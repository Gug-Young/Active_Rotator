# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import LogNorm

# %%
SF = np.load('DATA/SF_threshold.npz')
MF = np.load('DATA/MF_threshold.npz')
ER = np.load('DATA/ER_threshold.npz')

# %%
plt.figure(dpi=500)
plt.plot(MF['Ds'],MF['bs'],'rs-',label='Complete graph',zorder=3)
plt.plot(ER['Ds'],ER['bs'],'gs-',label='ER graph',zorder=2)
plt.plot(SF['Ds'],SF['bs'],'bs-',label='SF graph',zorder=1)
plt.xlim(0,4)
plt.ylim(0,1.3)
# plt.grid()
plt.xlabel(r'$D$',fontsize=15)
plt.ylabel(r'$b$',fontsize=15)
plt.text(1.0,0.5,'Periodic phase',fontsize=15,horizontalalignment='center',
        verticalalignment='center')
plt.text(3.0,1.0,'Stationary phase',fontsize=15,horizontalalignment='center',
        verticalalignment='center')

plt.legend()
plt.tight_layout()

# %%
AR_MF = np.load('DATA/MF N = 1000 db=0.04 K = 5 000.npz')

cs_mf = plt.contour(AR_MF['Ds'],AR_MF['bs'],AR_MF['D_chiij'].T,levels=[5],colors='red')
h_mf,_ = cs_mf.legend_elements()

AR_ER = np.load('DATA/ER N = 1000 mk = 6.0 db=0.04 K = 5 000.npz')


cs_er = plt.contour(AR_ER['Ds'],AR_ER['bs'],AR_ER['D_chiij'].T,levels=[5],colors='green')
h_er,_ = cs_er.legend_elements()


AR_SF = np.load('DATA/SF N = 1000 m = 3 db=0.04 000.npz')
cs_sf = plt.contour(AR_SF['Ds'],AR_SF['bs'],AR_SF['D_chiij'].T,levels=[5],colors='blue')
h_sf,_ = cs_sf.legend_elements()

plt.legend([h_mf[0],h_er[0],h_sf[0]],['Complete','ER','SF'])
plt.hlines(1.1,0,3.0,ls='--',color='black')
plt.ylim(0,1.5)
plt.xlim(0,3)
# Out:
# (0.0, 3.0)

# %%
MF_SR = AR_MF['D_mrij'].T - AR_MF['D_sij'].T
plt.pcolormesh(AR_MF['Ds'],AR_MF['bs'],MF_SR,cmap='gray',norm=LogNorm(vmin=1e-3, vmax=1))
plt.colorbar()
plt.plot(MF['Ds'],MF['bs'],'rs-',label='Complete graph',zorder=3)
plt.xlim(0,3)
plt.ylim(0,1.4)
# Out:
# (0.0, 1.4)

# %%
ER_SR = AR_ER['D_mrij'].T - AR_ER['D_sij'].T
plt.pcolormesh(AR_ER['Ds'],AR_ER['bs'],ER_SR,cmap='gray',norm=LogNorm(vmin=1e-3, vmax=1))
plt.colorbar()
plt.plot(ER['Ds'],ER['bs'],'rs-',label='Complete graph',zorder=3)
plt.xlim(0,3)
plt.ylim(0,1.4)
# Out:
# (0.0, 1.4)

# %%
SF_SR = AR_SF['D_mrij'].T - AR_SF['D_sij'].T
plt.pcolormesh(AR_SF['Ds'],AR_SF['bs'],SF_SR,cmap='gray',norm=LogNorm(vmin=1e-3, vmax=1))
plt.colorbar()
plt.plot(SF['Ds'],SF['bs'],'rs-',label='Complete graph',zorder=3)

plt.xlim(0,4)
plt.ylim(0,1.4)
# Out:
# (0.0, 1.4)

# %% [markdown]
# # TOTAL

# %%
fig,(ax1,ax2) = plt.subplots(2,1,sharex=True,sharey=True,figsize=(4,7),dpi=300)
plt.sca(ax1)
SF_SR = AR_SF['D_mrij'].T - AR_SF['D_sij'].T
plt.pcolormesh(AR_SF['Ds'],AR_SF['bs'],SF_SR,cmap='viridis',norm=LogNorm(vmin=1e-3, vmax=1))
plt.colorbar()
plt.plot(SF['Ds'],SF['bs'],'bs-',label='Complete graph',zorder=3)

plt.xlim(0,4)
plt.ylim(0,1.4)
# plt.xlabel(r'$D$',fontsize=15)
plt.ylabel(r'$b$',fontsize=15)
plt.title(r'$r-\sigma$',fontsize=15)
plt.suptitle('SF graph',fontsize=15)


plt.sca(ax2)
SF_SR = AR_SF['D_chiij'].T
plt.pcolormesh(AR_SF['Ds'],AR_SF['bs'],SF_SR,cmap='gray',norm=LogNorm(vmin=5, vmax=100))
plt.colorbar()
plt.plot(SF['Ds'],SF['bs'],'bs-',label='Complete graph',zorder=3)

plt.xlim(0,4)
plt.ylim(0,1.4)
plt.xlabel(r'$D$',fontsize=15)
plt.ylabel(r'$b$',fontsize=15)
plt.title(r'$\tilde{\chi}$',fontsize=15)
plt.tight_layout()

# %%
fig,(ax1,ax2) = plt.subplots(2,1,sharex=True,sharey=True,figsize=(4,7),dpi=300)
plt.sca(ax1)
ER_SR = AR_ER['D_mrij'].T - AR_ER['D_sij'].T
plt.pcolormesh(AR_ER['Ds'],AR_ER['bs'],ER_SR,cmap='viridis',norm=LogNorm(vmin=1e-3, vmax=1))
# plt.colorbar()
plt.plot(ER['Ds'],ER['bs'],'gs-',label='Complete graph',zorder=3)

plt.xlim(0,4)
plt.ylim(0,1.4)
# plt.xlabel(r'$D$',fontsize=15)
plt.ylabel(r'$b$',fontsize=15)
plt.title(r'$r-\sigma$',fontsize=15)
plt.suptitle('ER graph',fontsize=15)
plt.gca().set_aspect('auto')

plt.sca(ax2)
ER_SR = AR_ER['D_chiij'].T
plt.pcolormesh(AR_ER['Ds'],AR_ER['bs'],ER_SR,cmap='gray',norm=LogNorm(vmin=5, vmax=100))
# plt.colorbar()
plt.plot(ER['Ds'],ER['bs'],'gs-',label='Complete graph',zorder=3)

plt.xlim(0,4)
plt.ylim(0,1.4)
plt.xlabel(r'$D$',fontsize=15)
plt.ylabel(r'$b$',fontsize=15)
plt.title(r'$\tilde{\chi}$',fontsize=15)
plt.gca().set_aspect('auto')

plt.tight_layout()

# %%
fig,(ax1,ax2) = plt.subplots(2,1,sharex=True,sharey=True,figsize=(4,7),dpi=300)
plt.sca(ax1)
MF_SR = AR_MF['D_mrij'].T - AR_MF['D_sij'].T
plt.pcolormesh(AR_MF['Ds'],AR_MF['bs'],MF_SR,cmap='viridis',norm=LogNorm(vmin=1e-3, vmax=1))
# plt.colorbar()
plt.plot(MF['Ds'],MF['bs'],'rs-',label='Complete graph',zorder=3)

plt.xlim(0,4)
plt.ylim(0,1.4)
# plt.xlabel(r'$D$',fontsize=15)
plt.ylabel(r'$b$',fontsize=15)
plt.title(r'$r-\sigma$',fontsize=15)
plt.suptitle('Complete graph',fontsize=15)
plt.gca().set_aspect('auto')

plt.sca(ax2)
MF_SR = AR_MF['D_chiij'].T
plt.pcolormesh(AR_MF['Ds'],AR_MF['bs'],MF_SR,cmap='gray',norm=LogNorm(vmin=5, vmax=100))
# plt.colorbar()
plt.plot(MF['Ds'],MF['bs'],'rs-',label='Complete graph',zorder=3)

plt.xlim(0,4)
plt.ylim(0,1.4)
plt.xlabel(r'$D$',fontsize=15)
plt.ylabel(r'$b$',fontsize=15)
plt.title(r'$\tilde{\chi}$',fontsize=15)
plt.gca().set_aspect('auto')

plt.tight_layout()
plt.show()

# %% [markdown]
# # Graph

# %%
import networkx as nx
import numpy as np
import matplotlib.pyplot as plt
from networkx.drawing.nx_pydot import graphviz_layout

m = 3
G = nx.barabasi_albert_graph(1000,m,seed=0)
A = nx.adjacency_matrix(G)
Aij = A.todense()
Deg = Aij.sum(axis=1)
DegT = Deg.reshape(-1,1)
mk = Deg.mean()
print(mk)


# G = nx.gnp_random_graph(N, p, seed=10374196)

degree_sequence = sorted((d for n, d in G.degree()), reverse=True)
dmax = max(degree_sequence)

fig = plt.figure("Degree of a random graph", figsize=(8, 8))
# Create a gridspec for adding subplots of different sizes
axgrid = fig.add_gridspec(5, 4)

ax0 = fig.add_subplot(axgrid[0:3, :])

Gcc = G.subgraph(sorted(nx.connected_components(G), key=len, reverse=True)[0])
pos = nx.spring_layout(Gcc, seed=10396953)
# pos = graphviz_layout(Gcc, prog="twopi")

nx.draw_networkx_nodes(Gcc, pos, ax=ax0, node_size=20)
nx.draw_networkx_edges(Gcc, pos, ax=ax0, alpha=0.4)
ax0.set_title("Connected components of SF graph")
ax0.set_axis_off()

ax1 = fig.add_subplot(axgrid[3:, :2])
ax1.plot(degree_sequence, "b-", marker="o")
ax1.set_title("Degree Rank Plot")
ax1.set_ylabel("Degree")
ax1.set_xlabel("Rank")
plt.sca(ax1)
plt.loglog()

ax2 = fig.add_subplot(axgrid[3:, 2:])
ax2.bar(*np.unique(degree_sequence, return_counts=True))
ax2.set_title("Degree histogram")
ax2.set_xlabel("Degree")
ax2.set_ylabel("# of Nodes")
plt.sca(ax2)
plt.loglog()
fig.tight_layout()
plt.show()
# Out:
# /var/folders/lj/v2s5sd8n1cv2xdh0yw2kf0x00000gn/T/ipykernel_85716/271498773.py:8: FutureWarning: adjacency_matrix will return a scipy.sparse array instead of a matrix in Networkx 3.0.
#   A = nx.adjacency_matrix(G)
# 5.982
